# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
HOME='/content/drive/MyDrive/AnimalVITON/YOLO_Seg' # 폴더가 위치한 디렉토리

# %%
# !pip install ultralytics --quiet

# %%
# YAML 파일 절대경로로 수정
import yaml
import os

yaml_path = f'{HOME}/datasets/Dog_Cloth_Segmentation/data.yaml'

with open(yaml_path, 'r') as file:
    data = yaml.safe_load(file)

base_path = f'{HOME}/datasets/Dog_Cloth_Segmentation'
data['train'] = os.path.join(base_path, 'train/images')
data['val'] = os.path.join(base_path, 'valid/images')
data['test'] = os.path.join(base_path, 'test/images')

with open(yaml_path, 'w') as file:
    yaml.dump(data, file)

# %%
# %cd {HOME}
# !yolo task=segment mode=train model=yolov8n-seg.pt data=datasets/Dog_Cloth_Segmentation/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content/drive/MyDrive/AnimalVITON/YOLO_Seg
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
